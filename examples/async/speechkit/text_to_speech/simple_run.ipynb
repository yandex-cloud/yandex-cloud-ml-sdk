# %%
from yandex_cloud_ml_sdk import AsyncYCloudML
from yandex_cloud_ml_sdk._experimental.audio.out import AsyncAudioOut

SAMPLERATE = 44100

# %%
# You can set authentication using environment variables instead of the 'auth' argument:
# YC_OAUTH_TOKEN, YC_TOKEN, YC_IAM_TOKEN, or YC_API_KEY
# You can also set 'folder_id' using the YC_FOLDER_ID environment variable
sdk = AsyncYCloudML(
    # folder_id="<YC_FOLDER_ID>",
    # auth="<YC_API_KEY/YC_IAM_TOKEN>",
).setup_default_logging()

# %%
tts = sdk.speechkit.text_to_speech(
    voice='kirill',
    audio_format=f'PCM16({SAMPLERATE})',
)   
# you can configure TTS object after creation
tts = tts.configure(
    # alternative way to specify audio_format
    audio_format=tts.AudioFormat.PCM16(SAMPLERATE),
    loudness_normalization=tts.LoudnessNormalization.LUFS,
    speed=1.5,
)

# %%
gpt = sdk.chat.completions('aliceai-llm')
gpt = gpt.configure(max_tokens=100)
gpt_result = await gpt.run("Сгенерируй сказку на 500 символов про Yandex Cloud AI Studio")
query = gpt_result.text
query
# Out:
# 'В далёком цифровом королевстве жил‑был волшебный помощник — Yandex Cloud AI Studio. Он умел творить чудеса: сочинял истории, решал задачи и создавал идеи.\n\nОднажды к нему пришёл юный изобретатель. «Помоги создать чудо‑устройство!» — попросил он. AI Studio задумался, проанализировал тысячи схем и выдал идеальное решение.\n\nРадостный изобретатель построил устройство, и королевство расцвело. С тех пор все знали: если нужна помощь — иди к Yandex Cloud'

# %%
result = await tts.run(query)
print(f"Joined result [{result.start_ms}, {result.end_ms}]: {result.text}")
result
# Out:
# Joined result [0, 24989]: В далёком цифровом королевстве жил‑был волшебный помощник — Yandex Cloud AI Studio. Он умел творить чудеса: сочинял истории, решал задачи и создавал идеи. Однажды к нему пришёл юный изобретатель. «Помоги создать чудо‑устройство! » — попросил он. AI Studio задумался, проанализировал тысячи схем и выдал идеальное решение. Радостный изобретатель построил устройство, и королевство расцвело. С тех пор все знали: если нужна помощь — иди к Yandex Cloud
# PCM16
# TextToSpeechResult(chunks=(TextToSpeechChunk<data=b"...", text='В далёком цифровом королевстве жил‑был волшебный помощник — Yandex Cloud AI Studio.', segment=[0, 4237], length_ms=4237, size_bytes=373760>, TextToSpeechChunk<data=b"...", text='Он умел творить чудеса: сочинял истории, решал задачи и создавал идеи.', segment=[4237, 8499], length_ms=4262, size_bytes=375956>, TextToSpeechChunk<data=b"...", text='Однажды к нему пришёл юный изобретатель.', segment=[8499, 10753], length_ms=2254, size_bytes=198804>, TextToSpeechChunk<data=b"...", text='«Помоги создать чудо‑устройство!', segment=[10753, 12647], length_ms=1894, size_bytes=167060>, TextToSpeechChunk<data=b"...", text='» — попросил он.', segment=[12647, 13856], length_ms=1209, size_bytes=106644>, TextToSpeechChunk<data=b"...", text='AI Studio задумался, проанализировал тысячи схем и выдал идеальное решение.', segment=[13856, 18060], length_ms=4204, size_bytes=370836>, TextToSpeechChunk<data=b"...", text='Радостный изобретатель построил устройство, и королевство расцвело.', segment=[18060, 21498], length_ms=3438, size_bytes=303252>, TextToSpeechChunk<data=b"...", text='С тех пор все знали: если нужна помощь — иди к Yandex Cloud', segment=[21498, 24989], length_ms=3491, size_bytes=307976>))
