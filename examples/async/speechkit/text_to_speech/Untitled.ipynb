# %%
from yandex_cloud_ml_sdk import AsyncYCloudML
from yandex_cloud_ml_sdk._experimental.audio.out import AsyncAudioOut

SAMPLERATE = 44100

# %%
# You can set authentication using environment variables instead of the 'auth' argument:
# YC_OAUTH_TOKEN, YC_TOKEN, YC_IAM_TOKEN, or YC_API_KEY
# You can also set 'folder_id' using the YC_FOLDER_ID environment variable
sdk = AsyncYCloudML(
    # folder_id="<YC_FOLDER_ID>",
    # auth="<YC_API_KEY/YC_IAM_TOKEN>",
).setup_default_logging()

# %%
tts = sdk.speechkit.text_to_speech(
    voice='kirill',
    audio_format=f'PCM16({SAMPLERATE})',
)   
# you can configure TTS object after creation
tts = tts.configure(
    # alternative way to specify audio_format
    audio_format=tts.AudioFormat.PCM16(SAMPLERATE),
    loudness_normalization=tts.LoudnessNormalization.LUFS,
    speed=1.5,
)

# %%
gpt = sdk.chat.completions('aliceai-llm')
gpt = gpt.configure(max_tokens=100)
gpt_result = await gpt.run("Сгенерируй сказку на 500 символов про Yandex Cloud AI Studio")
query = gpt_result.text
query
# Out:
# 'В далёкой цифровой стране жил мудрый волшебник\u202f— Yandex Cloud AI Studio. Он помогал героям воплощать идеи: создавал тексты, рисовал картины, решал сложные загадки.\n\nОднажды к нему пришёл юный изобретатель. «Хочу создать чудо, но не знаю как!»\u202f— вздохнул он. Волшебник улыбнулся, протянул ему инструмент\u202f— и через миг идея обернулась реальным проектом.\n\nС тех пор все, кто мечтал о новом, шли к Yandex Cloud AI Studio\u202f— и'

# %%
result = await tts.run(query)
print(f"Joined result [{result.start_ms}, {result.end_ms}]: {result.text}")
# Out:
# Joined result [0, 23630]: В далёкой цифровой стране жил мудрый волшебник — Yandex Cloud AI Studio. Он помогал героям воплощать идеи: создавал тексты, рисовал картины, решал сложные загадки. Однажды к нему пришёл юный изобретатель. «Хочу создать чудо, но не знаю как! » — вздохнул он. Волшебник улыбнулся, протянул ему инструмент — и через миг идея обернулась реальным проектом. С тех пор все, кто мечтал о новом, шли к Yandex Cloud AI Studio — и

# %%
result
# Out:
# TextToSpeechResult(chunks=(TextToSpeechChunk<data=b"...", text='В далёкой цифровой стране жил мудрый волшебник\u202f— Yandex Cloud AI Studio.', segment=[0, 3959], length_ms=3959, size_bytes=349184>, TextToSpeechChunk<data=b"...", text='Он помогал героям воплощать идеи: создавал тексты, рисовал картины, решал сложные загадки.', segment=[3959, 8999], length_ms=5040, size_bytes=444564>, TextToSpeechChunk<data=b"...", text='Однажды к нему пришёл юный изобретатель.', segment=[8999, 11253], length_ms=2254, size_bytes=198804>, TextToSpeechChunk<data=b"...", text='«Хочу создать чудо, но не знаю как!', segment=[11253, 13414], length_ms=2161, size_bytes=190612>, TextToSpeechChunk<data=b"...", text='»\u202f— вздохнул он.', segment=[13414, 14750], length_ms=1336, size_bytes=117908>, TextToSpeechChunk<data=b"...", text='Волшебник улыбнулся, протянул ему инструмент\u202f— и через миг идея обернулась реальным проектом.', segment=[14750, 19523], length_ms=4773, size_bytes=421012>, TextToSpeechChunk<data=b"...", text='С тех пор все, кто мечтал о новом, шли к Yandex Cloud AI Studio\u202f— и', segment=[19523, 23630], length_ms=4107, size_bytes=362248>))
