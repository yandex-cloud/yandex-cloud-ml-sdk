# %%
from yandex_cloud_ml_sdk import YCloudML

SAMPLERATE = 44100

# %%
# You can set authentication using environment variables instead of the 'auth' argument:
# YC_OAUTH_TOKEN, YC_TOKEN, YC_IAM_TOKEN, or YC_API_KEY
# You can also set 'folder_id' using the YC_FOLDER_ID environment variable
sdk = YCloudML(
    # folder_id="<YC_FOLDER_ID>",
    # auth="<YC_API_KEY/YC_IAM_TOKEN>",
).setup_default_logging()

# %%
tts = sdk.speechkit.text_to_speech(
    voice='kirill',
    audio_format=f'PCM16({SAMPLERATE})',
)   
# you can configure TTS object after creation
tts = tts.configure(
    # alternative way to specify audio_format
    audio_format=tts.AudioFormat.PCM16(SAMPLERATE),
    loudness_normalization=tts.LoudnessNormalization.LUFS,
    speed=1.5,
)

# %%
gpt = sdk.chat.completions('aliceai-llm')
gpt = gpt.configure(max_tokens=100)
gpt_result = gpt.run("Сгенерируй сказку на 500 символов про Yandex Cloud AI Studio")
query = gpt_result.text
query
# Out:
# 'В далёкой цифровой стране жил‑был волшебник Yandex Cloud. Решил он создать чудо‑студию — AI Studio. Собрал он умные алгоритмы, дал им силу машинного обучения — и засияла студия ярким светом!\n\nПриходили к ней разработчики с задумками, а студия превращала идеи в умные сервисы: чат‑ботов, переводчиков, распознавателей. Чем больше творили — тем мудрее становилась AI Studio.\n\nИ по сей день помогает она людям творить невозможное — лишь'

# %%
result = tts.run(query)
print(f"Joined result [{result.start_ms}, {result.end_ms}]: {result.text}")
result
# Out:
# Joined result [0, 23592]: В далёкой цифровой стране жил‑был волшебник Yandex Cloud. Решил он создать чудо‑студию — AI Studio. Собрал он умные алгоритмы, дал им силу машинного обучения — и засияла студия ярким светом! Приходили к ней разработчики с задумками, а студия превращала идеи в умные сервисы: чат‑ботов, переводчиков, распознавателей. Чем больше творили — тем мудрее становилась AI Studio. И по сей день помогает она людям творить невозможное — лишь
# TextToSpeechResult(chunks=(TextToSpeechChunk<data=b"...", text='В далёкой цифровой стране жил‑был волшебник Yandex Cloud.', segment=[0, 2995], length_ms=2995, size_bytes=264192>, TextToSpeechChunk<data=b"...", text='Решил он создать чудо‑студию — AI Studio.', segment=[2995, 5597], length_ms=2602, size_bytes=229524>, TextToSpeechChunk<data=b"...", text='Собрал он умные алгоритмы, дал им силу машинного обучения — и засияла студия ярким светом!', segment=[5597, 10741], length_ms=5144, size_bytes=453780>, TextToSpeechChunk<data=b"...", text='Приходили к ней разработчики с задумками, а студия превращала идеи в умные сервисы: чат‑ботов, переводчиков, распознавателей.', segment=[10741, 17383], length_ms=6642, size_bytes=585876>, TextToSpeechChunk<data=b"...", text='Чем больше творили — тем мудрее становилась AI Studio.', segment=[17383, 20461], length_ms=3078, size_bytes=271508>, TextToSpeechChunk<data=b"...", text='И по сей день помогает она людям творить невозможное — лишь', segment=[20461, 23592], length_ms=3131, size_bytes=276232>))
